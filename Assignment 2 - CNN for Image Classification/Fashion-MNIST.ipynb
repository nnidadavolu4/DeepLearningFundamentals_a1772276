# %% [markdown]
# # Loading the dataset and visualizing it

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import fashion_mnist
from sklearn.model_selection import train_test_split
from tensorflow.keras import models
from tensorflow.keras import layers

# Load the Fashion-MNIST dataset
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# Split data into training and validation sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# Print the shapes of the new sets
print("Training set shape:", x_train.shape)
print("Training labels shape:", y_train.shape)

print("\nValidation set shape:", x_val.shape)
print("Validation set shape:", y_val.shape)

print("\nTest set shape:", x_test.shape)
print("Test labels shape:", y_test.shape)

# Define class names
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# # Plot first 10 samples
# plt.figure(figsize=(10, 10))
# for i in range(20):
#     plt.subplot(4, 5, i+1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.grid(False)
#     plt.imshow(x_train[i], cmap=plt.cm.binary)
#     plt.xlabel(class_names[y_train[i]])
# plt.show()

# # Print labels for first 10 samples
# print("\nLabels for the first 10 samples:")
# for i in range(20):
#     print(f"Sample {i+1}: {class_names[y_train[i]]} (class {y_train[i]})")
# Out:
# Training set shape: (48000, 28, 28)
# Training labels shape: (48000,)
#
# Validation set shape: (12000, 28, 28)
# Validation set shape: (12000,)
#
# Test set shape: (10000, 28, 28)
# Test labels shape: (10000,)

# %%
y_val[:5]
# Out:
# array([8, 8, 7, 4, 8], dtype=uint8)

# %% [markdown]
# # Normalize and reshape the data

# %%
# #Normalize the data

x_train = (x_train - 0.2860) / 0.3530
x_val = (x_val - 0.2860) / 0.3530
x_test = (x_test - 0.2860) / 0.3530

# %%
x_train = x_train.reshape(-1, 28, 28, 1)
x_val = x_val.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

x_train[0].shape
# Out:
# (28, 28, 1)

# %% [markdown]
# # Developing the CNN - layer by layer

# %%
cnn = models.Sequential([
    layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# # Complie and fit the CNN - Baseline

# %%
cnn.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
baseline_cnn = cnn.fit(x_train, y_train,
                  validation_data=(x_val, y_val),
                  epochs=50,
                  batch_size=32)
# Out:
# Epoch 1/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9176 - loss: 0.2167 - val_accuracy: 0.8880 - val_loss: 0.3376
# Epoch 2/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9193 - loss: 0.2123 - val_accuracy: 0.8833 - val_loss: 0.3780
# Epoch 3/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9246 - loss: 0.1972 - val_accuracy: 0.8898 - val_loss: 0.3338
# Epoch 4/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9279 - loss: 0.1918 - val_accuracy: 0.8908 - val_loss: 0.3561
# Epoch 5/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9295 - loss: 0.1881 - val_accuracy: 0.8907 - val_loss: 0.3650
# Epoch 6/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9320 - loss: 0.1786 - val_accuracy: 0.8813 - val_loss: 0.4289
# Epoch 7/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9314 - loss: 0.1762 - val_accuracy: 0.8892 - val_loss: 0.3715
# Epoch 8/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9368 - loss: 0.1669 - val_accuracy: 0.8855 - val_loss: 0.3996
# Epoch 9/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9371 - loss: 0.1617 - val_accuracy: 0.8838 - val_loss: 0.4455
# Epoch 10/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9406 - loss: 0.1607 - val_accuracy: 0.8856 - val_loss: 0.4497
# Epoch 11/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9416 - loss: 0.1559 - val_accuracy: 0.8942 - val_loss: 0.4464
# Epoch 12/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9423 - loss: 0.1573 - val_accuracy: 0.8955 - val_loss: 0.4254
# Epoch 13/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9444 - loss: 0.1449 - val_accuracy: 0.8903 - val_loss: 0.4534
# Epoch 14/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9439 - loss: 0.1514 - val_accuracy: 0.8949 - val_loss: 0.4902
# Epoch 15/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9492 - loss: 0.1388 - val_accuracy: 0.8849 - val_loss: 0.4679
# Epoch 16/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9493 - loss: 0.1359 - val_accuracy: 0.8863 - val_loss: 0.5034
# Epoch 17/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9503 - loss: 0.1326 - val_accuracy: 0.8921 - val_loss: 0.5681
# Epoch 18/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9526 - loss: 0.1251 - val_accuracy: 0.8918 - val_loss: 0.4662
# Epoch 19/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9552 - loss: 0.1240 - val_accuracy: 0.8870 - val_loss: 0.5165
# Epoch 20/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9513 - loss: 0.1365 - val_accuracy: 0.8900 - val_loss: 0.5590
# Epoch 21/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9512 - loss: 0.1311 - val_accuracy: 0.8906 - val_loss: 0.5751
# Epoch 22/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9565 - loss: 0.1179 - val_accuracy: 0.8840 - val_loss: 0.6397
# Epoch 23/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9529 - loss: 0.1262 - val_accuracy: 0.8915 - val_loss: 0.6076
# Epoch 24/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9557 - loss: 0.1262 - val_accuracy: 0.8876 - val_loss: 0.5924
# Epoch 25/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9578 - loss: 0.1150 - val_accuracy: 0.8873 - val_loss: 0.6570
# Epoch 26/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9548 - loss: 0.1256 - val_accuracy: 0.8890 - val_loss: 0.5948
# Epoch 27/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9589 - loss: 0.1151 - val_accuracy: 0.8932 - val_loss: 0.6530
# Epoch 28/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9581 - loss: 0.1113 - val_accuracy: 0.8928 - val_loss: 0.6107
# Epoch 29/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9615 - loss: 0.1075 - val_accuracy: 0.8895 - val_loss: 0.6738
# Epoch 30/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9603 - loss: 0.1099 - val_accuracy: 0.8863 - val_loss: 0.6150
# Epoch 31/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9574 - loss: 0.1219 - val_accuracy: 0.8875 - val_loss: 0.6176
# Epoch 32/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9610 - loss: 0.1106 - val_accuracy: 0.8885 - val_loss: 0.6735
# Epoch 33/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9601 - loss: 0.1021 - val_accuracy: 0.8860 - val_loss: 0.8096
# Epoch 34/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9557 - loss: 0.1295 - val_accuracy: 0.8863 - val_loss: 0.7413
# Epoch 35/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9613 - loss: 0.1113 - val_accuracy: 0.8820 - val_loss: 0.7971
# Epoch 36/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9626 - loss: 0.1032 - val_accuracy: 0.8783 - val_loss: 0.8517
# Epoch 37/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9612 - loss: 0.1036 - val_accuracy: 0.8842 - val_loss: 0.8238
# Epoch 38/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9611 - loss: 0.1217 - val_accuracy: 0.8899 - val_loss: 0.7816
# Epoch 39/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9670 - loss: 0.0888 - val_accuracy: 0.8819 - val_loss: 0.7669
# Epoch 40/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9611 - loss: 0.1105 - val_accuracy: 0.8867 - val_loss: 0.8033
# Epoch 41/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9638 - loss: 0.1053 - val_accuracy: 0.8880 - val_loss: 0.8595
# Epoch 42/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9640 - loss: 0.1092 - val_accuracy: 0.8807 - val_loss: 0.9103
# Epoch 43/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9635 - loss: 0.1031 - val_accuracy: 0.8895 - val_loss: 0.9262
# Epoch 44/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9652 - loss: 0.0952 - val_accuracy: 0.8810 - val_loss: 0.8437
# Epoch 45/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9620 - loss: 0.1124 - val_accuracy: 0.8823 - val_loss: 0.9120
# Epoch 46/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9677 - loss: 0.0909 - val_accuracy: 0.8868 - val_loss: 0.9117
# Epoch 47/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9651 - loss: 0.0984 - val_accuracy: 0.8827 - val_loss: 1.0424
# Epoch 48/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9637 - loss: 0.1067 - val_accuracy: 0.8855 - val_loss: 1.0153
# Epoch 49/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9682 - loss: 0.0960 - val_accuracy: 0.8885 - val_loss: 1.1343
# Epoch 50/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9657 - loss: 0.1037 - val_accuracy: 0.8906 - val_loss: 1.0866

# %% [markdown]
# # Training and Validation metrics for Baseline CNN

# %%
print(f"Final training accuracy: {baseline_cnn.history['accuracy'][-1]:.4f}")
print(f"Final validation accuracy: {baseline_cnn.history['val_accuracy'][-1]:.4f}")
print(f"Final training loss: {baseline_cnn.history['loss'][-1]:.4f}")
print(f"Final validation loss: {baseline_cnn.history['val_loss'][-1]:.4f}")

import matplotlib.pyplot as plt

# Plot training & validation accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(baseline_cnn.history['accuracy'])
plt.plot(baseline_cnn.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss
plt.subplot(1, 2, 2)
plt.plot(baseline_cnn.history['loss'])
plt.plot(baseline_cnn.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()
# Out:
# Final training accuracy: 0.9630
# Final validation accuracy: 0.8906
# Final training loss: 0.1087
# Final validation loss: 1.0866

# %%
# cnn.evaluate(x_test,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8834 - loss: 1.1341
# [1.1394610404968262, 0.8837000131607056]

# %% [markdown]
# # Classification report for Baseline CNN

# %%
# from sklearn.metrics import confusion_matrix , classification_report

# y_pred_cnn = cnn.predict(x_test)

# y_classes_cnn = [np.argmax(element) for element in y_pred_cnn]
# print("Classification Report: \n", classification_report(y_test, y_classes_cnn))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.88      0.83      1000
#            1       0.99      0.97      0.98      1000
#            2       0.79      0.84      0.81      1000
#            3       0.88      0.89      0.88      1000
#            4       0.81      0.81      0.81      1000
#            5       0.98      0.97      0.98      1000
#            6       0.71      0.58      0.64      1000
#            7       0.95      0.96      0.96      1000
#            8       0.97      0.98      0.97      1000
#            9       0.96      0.96      0.96      1000
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000

# %% [markdown]
# # AlexNet Implementation

# %%
from tensorflow.keras import layers, models

def create_alexnet():
    model = models.Sequential([
        # First Convolutional Layer
        layers.Conv2D(filters=96, kernel_size=(3,3), strides=(1,1), activation='relu', input_shape=(28,28,1)),
        layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)),

        # Second Convolutional Layer
        layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
        layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)),

        # Third Convolutional Layer
        layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),

        # Fourth Convolutional Layer
        layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),

        # Fifth Convolutional Layer
        layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
        layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)),

        # Flatten layer
        layers.Flatten(),

        # Fully connected layers
        layers.Dense(4096, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(4096, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(10, activation='softmax')
    ])

    return model

alexnet = create_alexnet()
alexnet.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Print model summary
alexnet.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_17 (Conv2D)                   │ (None, 26, 26, 96)          │             960 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_11 (MaxPooling2D)      │ (None, 13, 13, 96)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_18 (Conv2D)                   │ (None, 13, 13, 256)         │         221,440 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_12 (MaxPooling2D)      │ (None, 6, 6, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_19 (Conv2D)                   │ (None, 6, 6, 384)           │         885,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_20 (Conv2D)                   │ (None, 6, 6, 384)           │       1,327,488 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_21 (Conv2D)                   │ (None, 6, 6, 256)           │         884,992 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_13 (MaxPooling2D)      │ (None, 3, 3, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_4 (Flatten)                  │ (None, 2304)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 4096)                │       9,441,280 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 4096)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 4096)                │      16,781,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 4096)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 10)                  │          40,970 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 29,583,562 (112.85 MB)
#  Trainable params: 29,583,562 (112.85 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
baseline_alexnet = alexnet.fit(x_train, y_train,
                              batch_size=128,
                              epochs=50,
                              validation_data=(x_val, y_val),
                              verbose=1)
# Out:
# Epoch 1/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - accuracy: 0.9280 - loss: 0.1934 - val_accuracy: 0.8967 - val_loss: 0.3124
# Epoch 2/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - accuracy: 0.9295 - loss: 0.1953 - val_accuracy: 0.9012 - val_loss: 0.2956
# Epoch 3/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - accuracy: 0.9311 - loss: 0.1933 - val_accuracy: 0.9027 - val_loss: 0.2954
# Epoch 4/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 23s 44ms/step - accuracy: 0.9306 - loss: 0.1973 - val_accuracy: 0.9050 - val_loss: 0.3048
# Epoch 5/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 15s 39ms/step - accuracy: 0.9349 - loss: 0.1853 - val_accuracy: 0.9050 - val_loss: 0.3182
# Epoch 6/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 16s 42ms/step - accuracy: 0.9384 - loss: 0.1724 - val_accuracy: 0.9053 - val_loss: 0.3025
# Epoch 7/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 16s 42ms/step - accuracy: 0.9391 - loss: 0.1719 - val_accuracy: 0.8989 - val_loss: 0.3155
# Epoch 8/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 15s 40ms/step - accuracy: 0.9367 - loss: 0.1822 - val_accuracy: 0.9062 - val_loss: 0.3077
# Epoch 9/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 15s 39ms/step - accuracy: 0.9445 - loss: 0.1584 - val_accuracy: 0.9020 - val_loss: 0.3205
# Epoch 10/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 39ms/step - accuracy: 0.9428 - loss: 0.1658 - val_accuracy: 0.8974 - val_loss: 0.3418
# Epoch 11/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - accuracy: 0.9439 - loss: 0.1547 - val_accuracy: 0.8985 - val_loss: 0.3387
# Epoch 12/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 15s 41ms/step - accuracy: 0.9441 - loss: 0.1693 - val_accuracy: 0.9050 - val_loss: 0.3346
# Epoch 13/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 15s 40ms/step - accuracy: 0.9469 - loss: 0.1562 - val_accuracy: 0.8928 - val_loss: 0.3714
# Epoch 14/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 15s 39ms/step - accuracy: 0.9489 - loss: 0.1568 - val_accuracy: 0.8997 - val_loss: 0.3479
# Epoch 15/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 39ms/step - accuracy: 0.9515 - loss: 0.1510 - val_accuracy: 0.8988 - val_loss: 0.3603
# Epoch 16/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 15s 39ms/step - accuracy: 0.9558 - loss: 0.1309 - val_accuracy: 0.8941 - val_loss: 0.3825
# Epoch 17/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - accuracy: 0.9491 - loss: 0.1585 - val_accuracy: 0.8954 - val_loss: 0.3916
# Epoch 18/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - accuracy: 0.9572 - loss: 0.1314 - val_accuracy: 0.8978 - val_loss: 0.3982
# Epoch 19/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 15s 39ms/step - accuracy: 0.9528 - loss: 0.1401 - val_accuracy: 0.8992 - val_loss: 0.3977
# Epoch 20/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - accuracy: 0.9487 - loss: 0.1613 - val_accuracy: 0.9021 - val_loss: 0.3791
# Epoch 21/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - accuracy: 0.9541 - loss: 0.1450 - val_accuracy: 0.9003 - val_loss: 0.3878
# Epoch 22/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 38ms/step - accuracy: 0.9588 - loss: 0.1270 - val_accuracy: 0.9013 - val_loss: 0.3577
# Epoch 23/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - accuracy: 0.9570 - loss: 0.1337 - val_accuracy: 0.8964 - val_loss: 0.4222
# Epoch 24/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 15s 39ms/step - accuracy: 0.9555 - loss: 0.1424 - val_accuracy: 0.8937 - val_loss: 0.4192
# Epoch 25/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - accuracy: 0.9536 - loss: 0.1476 - val_accuracy: 0.9034 - val_loss: 0.3514
# Epoch 26/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - accuracy: 0.9639 - loss: 0.1097 - val_accuracy: 0.9051 - val_loss: 0.4449
# Epoch 27/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 15s 39ms/step - accuracy: 0.9649 - loss: 0.1026 - val_accuracy: 0.8986 - val_loss: 0.3945
# Epoch 28/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - accuracy: 0.9645 - loss: 0.1103 - val_accuracy: 0.8989 - val_loss: 0.4233
# Epoch 29/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 15s 39ms/step - accuracy: 0.9514 - loss: 0.1524 - val_accuracy: 0.9034 - val_loss: 0.4479
# Epoch 30/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 39ms/step - accuracy: 0.9572 - loss: 0.1430 - val_accuracy: 0.8979 - val_loss: 0.3839
# Epoch 31/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - accuracy: 0.9615 - loss: 0.1183 - val_accuracy: 0.9048 - val_loss: 0.4654
# Epoch 32/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - accuracy: 0.9687 - loss: 0.1043 - val_accuracy: 0.9013 - val_loss: 0.3915
# Epoch 33/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - accuracy: 0.9601 - loss: 0.1384 - val_accuracy: 0.9039 - val_loss: 0.4813
# Epoch 34/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - accuracy: 0.9640 - loss: 0.1290 - val_accuracy: 0.9013 - val_loss: 0.4460
# Epoch 35/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 39ms/step - accuracy: 0.9653 - loss: 0.1129 - val_accuracy: 0.9014 - val_loss: 0.4479
# Epoch 36/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - accuracy: 0.9728 - loss: 0.0870 - val_accuracy: 0.9029 - val_loss: 0.4705
# Epoch 37/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - accuracy: 0.9739 - loss: 0.0854 - val_accuracy: 0.8975 - val_loss: 0.4401
# Epoch 38/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 39ms/step - accuracy: 0.9673 - loss: 0.1062 - val_accuracy: 0.9005 - val_loss: 0.4896
# Epoch 39/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - accuracy: 0.9698 - loss: 0.0985 - val_accuracy: 0.8948 - val_loss: 0.5017
# Epoch 40/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - accuracy: 0.9539 - loss: 0.1771 - val_accuracy: 0.8902 - val_loss: 0.4510
# Epoch 41/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 15s 39ms/step - accuracy: 0.9631 - loss: 0.1215 - val_accuracy: 0.8983 - val_loss: 0.4885
# Epoch 42/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - accuracy: 0.9587 - loss: 0.1635 - val_accuracy: 0.8968 - val_loss: 0.4467
# Epoch 43/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - accuracy: 0.9671 - loss: 0.1120 - val_accuracy: 0.8997 - val_loss: 0.4774
# Epoch 44/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - accuracy: 0.9678 - loss: 0.1164 - val_accuracy: 0.9055 - val_loss: 0.4678
# Epoch 45/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - accuracy: 0.9781 - loss: 0.0738 - val_accuracy: 0.9010 - val_loss: 0.4772
# Epoch 46/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - accuracy: 0.9699 - loss: 0.1027 - val_accuracy: 0.9007 - val_loss: 0.4141
# Epoch 47/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.9710 - loss: 0.1073 - val_accuracy: 0.8988 - val_loss: 0.6026
# Epoch 48/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 39ms/step - accuracy: 0.9579 - loss: 0.1627 - val_accuracy: 0.8945 - val_loss: 0.4629
# Epoch 49/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - accuracy: 0.9505 - loss: 0.2081 - val_accuracy: 0.9043 - val_loss: 0.5156
# Epoch 50/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 38ms/step - accuracy: 0.9753 - loss: 0.0882 - val_accuracy: 0.9028 - val_loss: 0.6197

# %%
print(f"Final training accuracy: {baseline_alexnet.history['accuracy'][-1]:.4f}")
print(f"Final validation accuracy: {baseline_alexnet.history['val_accuracy'][-1]:.4f}")
print(f"Final training loss: {baseline_alexnet.history['loss'][-1]:.4f}")
print(f"Final validation loss: {baseline_alexnet.history['val_loss'][-1]:.4f}")

import matplotlib.pyplot as plt

# Plot training & validation accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(baseline_alexnet.history['accuracy'])
plt.plot(baseline_alexnet.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss
plt.subplot(1, 2, 2)
plt.plot(baseline_alexnet.history['loss'])
plt.plot(baseline_alexnet.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()
# Out:
# Final training accuracy: 0.9721
# Final validation accuracy: 0.9028
# Final training loss: 0.0984
# Final validation loss: 0.6197

# %%
# alexnet.evaluate(x_test,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8971 - loss: 0.7481
# [0.7592343688011169, 0.8942999839782715]

# %%
# from sklearn.metrics import confusion_matrix , classification_report

# y_pred_alexnet = alexnet.predict(x_test)

# y_classes_alexnet = [np.argmax(element) for element in y_pred_alexnet]
# print("Classification Report: \n", classification_report(y_test, y_classes_alexnet))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.85      0.84      1000
#            1       0.99      0.97      0.98      1000
#            2       0.80      0.88      0.84      1000
#            3       0.87      0.92      0.89      1000
#            4       0.84      0.83      0.83      1000
#            5       0.98      0.97      0.98      1000
#            6       0.75      0.61      0.67      1000
#            7       0.95      0.96      0.96      1000
#            8       0.98      0.98      0.98      1000
#            9       0.96      0.96      0.96      1000
#
#     accuracy                           0.89     10000
#    macro avg       0.89      0.89      0.89     10000
# weighted avg       0.89      0.89      0.89     10000

# %% [markdown]
# # LeNet-5 Implementation

# %%
def create_lenet5():
    model = models.Sequential([
        layers.Conv2D(6, 5, activation='relu', input_shape=(28, 28, 1)),
        layers.MaxPooling2D(2),
        layers.Conv2D(16, 5, activation='relu'),
        layers.MaxPooling2D(2),
        layers.Flatten(),
        layers.Dense(120, activation='relu'),
        layers.Dense(84, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])
    return model

lenet5_baseline = create_lenet5()
lenet5_baseline.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history_lenet5 = lenet5_baseline.fit(x_train, y_train, batch_size=128, epochs=50, validation_data=(x_val, y_val), verbose=1)


lenet5_baseline.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.5755 - loss: 5.4166 - val_accuracy: 0.7412 - val_loss: 0.7353
# Epoch 2/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7654 - loss: 0.6526 - val_accuracy: 0.7908 - val_loss: 0.5835
# Epoch 3/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8107 - loss: 0.5236 - val_accuracy: 0.8131 - val_loss: 0.5364
# Epoch 4/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8356 - loss: 0.4574 - val_accuracy: 0.8242 - val_loss: 0.5004
# Epoch 5/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8444 - loss: 0.4219 - val_accuracy: 0.8296 - val_loss: 0.4905
# Epoch 6/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8524 - loss: 0.3960 - val_accuracy: 0.8353 - val_loss: 0.4720
# Epoch 7/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8621 - loss: 0.3677 - val_accuracy: 0.8405 - val_loss: 0.4537
# Epoch 8/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8698 - loss: 0.3491 - val_accuracy: 0.8363 - val_loss: 0.4522
# Epoch 9/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8697 - loss: 0.3429 - val_accuracy: 0.8457 - val_loss: 0.4566
# Epoch 10/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8797 - loss: 0.3181 - val_accuracy: 0.8454 - val_loss: 0.4455
# Epoch 11/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8859 - loss: 0.3042 - val_accuracy: 0.8467 - val_loss: 0.4406
# Epoch 12/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8889 - loss: 0.2919 - val_accuracy: 0.8477 - val_loss: 0.4553
# Epoch 13/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8920 - loss: 0.2839 - val_accuracy: 0.8522 - val_loss: 0.4371
# Epoch 14/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8946 - loss: 0.2778 - val_accuracy: 0.8460 - val_loss: 0.4505
# Epoch 15/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8919 - loss: 0.2796 - val_accuracy: 0.8526 - val_loss: 0.4562
# Epoch 16/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8998 - loss: 0.2587 - val_accuracy: 0.8569 - val_loss: 0.4463
# Epoch 17/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9068 - loss: 0.2453 - val_accuracy: 0.8608 - val_loss: 0.4460
# Epoch 18/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9079 - loss: 0.2424 - val_accuracy: 0.8495 - val_loss: 0.4759
# Epoch 19/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9072 - loss: 0.2404 - val_accuracy: 0.8608 - val_loss: 0.4460
# Epoch 20/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9111 - loss: 0.2288 - val_accuracy: 0.8613 - val_loss: 0.4491
# Epoch 21/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9171 - loss: 0.2230 - val_accuracy: 0.8605 - val_loss: 0.4725
# Epoch 22/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9174 - loss: 0.2186 - val_accuracy: 0.8543 - val_loss: 0.4689
# Epoch 23/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9210 - loss: 0.2047 - val_accuracy: 0.8526 - val_loss: 0.4778
# Epoch 24/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9190 - loss: 0.2099 - val_accuracy: 0.8593 - val_loss: 0.4741
# Epoch 25/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9252 - loss: 0.1951 - val_accuracy: 0.8638 - val_loss: 0.4858
# Epoch 26/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9255 - loss: 0.1926 - val_accuracy: 0.8639 - val_loss: 0.5073
# Epoch 27/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9308 - loss: 0.1816 - val_accuracy: 0.8598 - val_loss: 0.5394
# Epoch 28/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9320 - loss: 0.1810 - val_accuracy: 0.8595 - val_loss: 0.4898
# Epoch 29/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9250 - loss: 0.1886 - val_accuracy: 0.8598 - val_loss: 0.5136
# Epoch 30/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9280 - loss: 0.1809 - val_accuracy: 0.8608 - val_loss: 0.5159
# Epoch 31/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9347 - loss: 0.1710 - val_accuracy: 0.8613 - val_loss: 0.5339
# Epoch 32/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9376 - loss: 0.1590 - val_accuracy: 0.8605 - val_loss: 0.5396
# Epoch 33/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9395 - loss: 0.1581 - val_accuracy: 0.8618 - val_loss: 0.5704
# Epoch 34/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9407 - loss: 0.1540 - val_accuracy: 0.8577 - val_loss: 0.5682
# Epoch 35/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9367 - loss: 0.1622 - val_accuracy: 0.8621 - val_loss: 0.5976
# Epoch 36/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9397 - loss: 0.1557 - val_accuracy: 0.8629 - val_loss: 0.5996
# Epoch 37/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9451 - loss: 0.1427 - val_accuracy: 0.8583 - val_loss: 0.6097
# Epoch 38/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9414 - loss: 0.1503 - val_accuracy: 0.8596 - val_loss: 0.6109
# Epoch 39/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9457 - loss: 0.1405 - val_accuracy: 0.8624 - val_loss: 0.6334
# Epoch 40/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9467 - loss: 0.1389 - val_accuracy: 0.8586 - val_loss: 0.6074
# Epoch 41/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9456 - loss: 0.1408 - val_accuracy: 0.8608 - val_loss: 0.6323
# Epoch 42/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9524 - loss: 0.1254 - val_accuracy: 0.8629 - val_loss: 0.6964
# Epoch 43/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9502 - loss: 0.1307 - val_accuracy: 0.8558 - val_loss: 0.7194
# Epoch 44/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9475 - loss: 0.1348 - val_accuracy: 0.8651 - val_loss: 0.6666
# Epoch 45/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9556 - loss: 0.1155 - val_accuracy: 0.8577 - val_loss: 0.7446
# Epoch 46/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9521 - loss: 0.1306 - val_accuracy: 0.8561 - val_loss: 0.7171
# Epoch 47/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9513 - loss: 0.1233 - val_accuracy: 0.8594 - val_loss: 0.7533
# Epoch 48/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9546 - loss: 0.1200 - val_accuracy: 0.8572 - val_loss: 0.7325
# Epoch 49/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9575 - loss: 0.1126 - val_accuracy: 0.8596 - val_loss: 0.7024
# Epoch 50/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9536 - loss: 0.1274 - val_accuracy: 0.8618 - val_loss: 0.7766
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_58 (Conv2D)                   │ (None, 24, 24, 6)           │             156 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_20 (MaxPooling2D)      │ (None, 12, 12, 6)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_59 (Conv2D)                   │ (None, 8, 8, 16)            │           2,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_21 (MaxPooling2D)      │ (None, 4, 4, 16)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_8 (Flatten)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_27 (Dense)                     │ (None, 120)                 │          30,840 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_28 (Dense)                     │ (None, 84)                  │          10,164 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_29 (Dense)                     │ (None, 10)                  │             850 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 133,280 (520.63 KB)
#  Trainable params: 44,426 (173.54 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 88,854 (347.09 KB)

# %%
print(f"Final training accuracy: {history_lenet5.history['accuracy'][-1]:.4f}")
print(f"Final validation accuracy: {history_lenet5.history['val_accuracy'][-1]:.4f}")
print(f"Final training loss: {history_lenet5.history['loss'][-1]:.4f}")
print(f"Final validation loss: {history_lenet5.history['val_loss'][-1]:.4f}")

import matplotlib.pyplot as plt

# Plot training & validation accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history_lenet5.history['accuracy'])
plt.plot(history_lenet5.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss
plt.subplot(1, 2, 2)
plt.plot(history_lenet5.history['loss'])
plt.plot(history_lenet5.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()
# Out:
# Final training accuracy: 0.9509
# Final validation accuracy: 0.8618
# Final training loss: 0.1325
# Final validation loss: 0.7766

# %%
# lenet5_baseline.evaluate(x_test,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8586 - loss: 0.8310
# [0.8346583247184753, 0.8557000160217285]

# %%
# from sklearn.metrics import confusion_matrix , classification_report

# y_pred_lenet5 = lenet5_baseline.predict(x_test)

# y_classes_lenet5 = [np.argmax(element) for element in y_pred_lenet5]
# print("Classification Report: \n", classification_report(y_test, y_classes_lenet5))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.82      0.79      1000
#            1       0.98      0.96      0.97      1000
#            2       0.77      0.78      0.77      1000
#            3       0.88      0.86      0.87      1000
#            4       0.74      0.79      0.76      1000
#            5       0.96      0.95      0.96      1000
#            6       0.67      0.55      0.60      1000
#            7       0.93      0.95      0.94      1000
#            8       0.92      0.96      0.94      1000
#            9       0.95      0.95      0.95      1000
#
#     accuracy                           0.86     10000
#    macro avg       0.85      0.86      0.85     10000
# weighted avg       0.85      0.86      0.85     10000

# %% [markdown]
# # ResNet-50 Implementation

# %%
from tensorflow.keras import layers, models

def create_resnet_block(inputs, filters, kernel_size=3, stride=1, conv_shortcut=False):
    x = layers.Conv2D(filters, kernel_size, strides=stride, padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters, kernel_size, padding='same')(x)
    x = layers.BatchNormalization()(x)

    if conv_shortcut:
        shortcut = layers.Conv2D(filters, 1, strides=stride, padding='same')(inputs)
        shortcut = layers.BatchNormalization()(shortcut)
    else:
        shortcut = inputs

    x = layers.Add()([x, shortcut])
    x = layers.Activation('relu')(x)
    return x

def create_resnet():
    inputs = layers.Input(shape=(28, 28, 1))

    x = layers.Conv2D(32, 3, strides=1, padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = create_resnet_block(x, 32)
    x = create_resnet_block(x, 32)

    x = create_resnet_block(x, 64, stride=2, conv_shortcut=True)
    x = create_resnet_block(x, 64)

    x = create_resnet_block(x, 128, stride=2, conv_shortcut=True)
    x = create_resnet_block(x, 128)

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(128, activation='relu')(x)
    outputs = layers.Dense(10, activation='softmax')(x)

    model = models.Model(inputs, outputs)
    return model

# Create the ResNet model
resnet_baseline = create_resnet()

# Compile the model
resnet_baseline.compile(optimizer='adam',
               loss='sparse_categorical_crossentropy',
               metrics=['accuracy'])

history_resnet_baseline = resnet_baseline.fit(x_train, y_train, batch_size=128, epochs=50, validation_data=(x_val, y_val), verbose=1)


resnet_baseline.summary()
# Out:
# Epoch 1/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 71s 149ms/step - accuracy: 0.7669 - loss: 0.6476 - val_accuracy: 0.7625 - val_loss: 0.6646
# Epoch 2/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 12s 32ms/step - accuracy: 0.8952 - loss: 0.2821 - val_accuracy: 0.8541 - val_loss: 0.4270
# Epoch 3/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.9133 - loss: 0.2381 - val_accuracy: 0.8628 - val_loss: 0.3968
# Epoch 4/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 12s 31ms/step - accuracy: 0.9256 - loss: 0.2045 - val_accuracy: 0.8043 - val_loss: 0.5906
# Epoch 5/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 33ms/step - accuracy: 0.9358 - loss: 0.1740 - val_accuracy: 0.9063 - val_loss: 0.2672
# Epoch 6/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 31ms/step - accuracy: 0.9423 - loss: 0.1573 - val_accuracy: 0.8813 - val_loss: 0.3434
# Epoch 7/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 12s 32ms/step - accuracy: 0.9513 - loss: 0.1335 - val_accuracy: 0.8749 - val_loss: 0.3623
# Epoch 8/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 31ms/step - accuracy: 0.9586 - loss: 0.1144 - val_accuracy: 0.9038 - val_loss: 0.3191
# Epoch 9/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 12s 31ms/step - accuracy: 0.9638 - loss: 0.1009 - val_accuracy: 0.9011 - val_loss: 0.3345
# Epoch 10/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 33ms/step - accuracy: 0.9670 - loss: 0.0913 - val_accuracy: 0.9187 - val_loss: 0.2563
# Epoch 11/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 12s 31ms/step - accuracy: 0.9736 - loss: 0.0707 - val_accuracy: 0.9034 - val_loss: 0.3251
# Epoch 12/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 12s 31ms/step - accuracy: 0.9787 - loss: 0.0585 - val_accuracy: 0.9110 - val_loss: 0.3344
# Epoch 13/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 33ms/step - accuracy: 0.9823 - loss: 0.0490 - val_accuracy: 0.8911 - val_loss: 0.4138
# Epoch 14/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.9827 - loss: 0.0475 - val_accuracy: 0.9012 - val_loss: 0.3887
# Epoch 15/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.9867 - loss: 0.0384 - val_accuracy: 0.8822 - val_loss: 0.5163
# Epoch 16/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.9882 - loss: 0.0333 - val_accuracy: 0.8945 - val_loss: 0.5181
# Epoch 17/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 33ms/step - accuracy: 0.9881 - loss: 0.0336 - val_accuracy: 0.8638 - val_loss: 0.6645
# Epoch 18/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.9865 - loss: 0.0384 - val_accuracy: 0.9119 - val_loss: 0.3887
# Epoch 19/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.9906 - loss: 0.0261 - val_accuracy: 0.9012 - val_loss: 0.4456
# Epoch 20/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.9905 - loss: 0.0256 - val_accuracy: 0.8882 - val_loss: 0.4929
# Epoch 21/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 12s 32ms/step - accuracy: 0.9928 - loss: 0.0208 - val_accuracy: 0.9155 - val_loss: 0.4069
# Epoch 22/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.9918 - loss: 0.0229 - val_accuracy: 0.9121 - val_loss: 0.4101
# Epoch 23/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 12s 32ms/step - accuracy: 0.9922 - loss: 0.0229 - val_accuracy: 0.8973 - val_loss: 0.4866
# Epoch 24/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 12s 32ms/step - accuracy: 0.9947 - loss: 0.0145 - val_accuracy: 0.9004 - val_loss: 0.5725
# Epoch 25/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 13s 34ms/step - accuracy: 0.9888 - loss: 0.0303 - val_accuracy: 0.9209 - val_loss: 0.3575
# Epoch 26/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 34ms/step - accuracy: 0.9934 - loss: 0.0189 - val_accuracy: 0.8979 - val_loss: 0.6020
# Epoch 27/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.9958 - loss: 0.0119 - val_accuracy: 0.9075 - val_loss: 0.5358
# Epoch 28/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.9935 - loss: 0.0179 - val_accuracy: 0.9013 - val_loss: 0.5421
# Epoch 29/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - accuracy: 0.9929 - loss: 0.0211 - val_accuracy: 0.9119 - val_loss: 0.5154
# Epoch 30/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 12s 32ms/step - accuracy: 0.9937 - loss: 0.0173 - val_accuracy: 0.9018 - val_loss: 0.5071
# Epoch 31/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 12s 32ms/step - accuracy: 0.9947 - loss: 0.0143 - val_accuracy: 0.9199 - val_loss: 0.4296
# Epoch 32/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 33ms/step - accuracy: 0.9947 - loss: 0.0153 - val_accuracy: 0.8954 - val_loss: 0.6165
# Epoch 33/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.9938 - loss: 0.0161 - val_accuracy: 0.9047 - val_loss: 0.5210
# Epoch 34/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 33ms/step - accuracy: 0.9952 - loss: 0.0140 - val_accuracy: 0.9144 - val_loss: 0.4576
# Epoch 35/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.9968 - loss: 0.0087 - val_accuracy: 0.9143 - val_loss: 0.4986
# Epoch 36/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - accuracy: 0.9953 - loss: 0.0134 - val_accuracy: 0.9136 - val_loss: 0.4953
# Epoch 37/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 12s 32ms/step - accuracy: 0.9951 - loss: 0.0140 - val_accuracy: 0.9157 - val_loss: 0.4674
# Epoch 38/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 12s 32ms/step - accuracy: 0.9949 - loss: 0.0151 - val_accuracy: 0.9217 - val_loss: 0.4277
# Epoch 39/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 33ms/step - accuracy: 0.9962 - loss: 0.0092 - val_accuracy: 0.8952 - val_loss: 0.6855
# Epoch 40/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - accuracy: 0.9956 - loss: 0.0129 - val_accuracy: 0.9196 - val_loss: 0.4771
# Epoch 41/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.9956 - loss: 0.0119 - val_accuracy: 0.8990 - val_loss: 0.6484
# Epoch 42/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.9966 - loss: 0.0096 - val_accuracy: 0.9257 - val_loss: 0.4434
# Epoch 43/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.9964 - loss: 0.0104 - val_accuracy: 0.9190 - val_loss: 0.4378
# Epoch 44/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 12s 32ms/step - accuracy: 0.9968 - loss: 0.0096 - val_accuracy: 0.9163 - val_loss: 0.4814
# Epoch 45/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 12s 32ms/step - accuracy: 0.9962 - loss: 0.0094 - val_accuracy: 0.9115 - val_loss: 0.5681
# Epoch 46/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.9952 - loss: 0.0138 - val_accuracy: 0.9150 - val_loss: 0.4973
# Epoch 47/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 12s 32ms/step - accuracy: 0.9968 - loss: 0.0099 - val_accuracy: 0.9251 - val_loss: 0.4379
# Epoch 48/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.9970 - loss: 0.0092 - val_accuracy: 0.9198 - val_loss: 0.4517
# Epoch 49/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.9966 - loss: 0.0101 - val_accuracy: 0.9208 - val_loss: 0.4618
# Epoch 50/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.9969 - loss: 0.0088 - val_accuracy: 0.8817 - val_loss: 0.8123
# Model: "functional_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_11            │ (None, 28, 28, 1)      │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_60 (Conv2D)        │ (None, 28, 28, 32)     │            320 │ input_layer_11[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_30    │ (None, 28, 28, 32)     │            128 │ conv2d_60[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_26             │ (None, 28, 28, 32)     │              0 │ batch_normalization_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_61 (Conv2D)        │ (None, 28, 28, 32)     │          9,248 │ activation_26[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_31    │ (None, 28, 28, 32)     │            128 │ conv2d_61[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_27             │ (None, 28, 28, 32)     │              0 │ batch_normalization_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_62 (Conv2D)        │ (None, 28, 28, 32)     │          9,248 │ activation_27[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_32    │ (None, 28, 28, 32)     │            128 │ conv2d_62[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_12 (Add)              │ (None, 28, 28, 32)     │              0 │ batch_normalization_3… │
# │                           │                        │                │ activation_26[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_28             │ (None, 28, 28, 32)     │              0 │ add_12[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_63 (Conv2D)        │ (None, 28, 28, 32)     │          9,248 │ activation_28[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_33    │ (None, 28, 28, 32)     │            128 │ conv2d_63[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_29             │ (None, 28, 28, 32)     │              0 │ batch_normalization_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_64 (Conv2D)        │ (None, 28, 28, 32)     │          9,248 │ activation_29[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_34    │ (None, 28, 28, 32)     │            128 │ conv2d_64[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_13 (Add)              │ (None, 28, 28, 32)     │              0 │ batch_normalization_3… │
# │                           │                        │                │ activation_28[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_30             │ (None, 28, 28, 32)     │              0 │ add_13[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_65 (Conv2D)        │ (None, 14, 14, 64)     │         18,496 │ activation_30[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_35    │ (None, 14, 14, 64)     │            256 │ conv2d_65[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_31             │ (None, 14, 14, 64)     │              0 │ batch_normalization_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_66 (Conv2D)        │ (None, 14, 14, 64)     │         36,928 │ activation_31[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_67 (Conv2D)        │ (None, 14, 14, 64)     │          2,112 │ activation_30[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_36    │ (None, 14, 14, 64)     │            256 │ conv2d_66[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_37    │ (None, 14, 14, 64)     │            256 │ conv2d_67[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_14 (Add)              │ (None, 14, 14, 64)     │              0 │ batch_normalization_3… │
# │                           │                        │                │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_32             │ (None, 14, 14, 64)     │              0 │ add_14[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_68 (Conv2D)        │ (None, 14, 14, 64)     │         36,928 │ activation_32[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_38    │ (None, 14, 14, 64)     │            256 │ conv2d_68[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_33             │ (None, 14, 14, 64)     │              0 │ batch_normalization_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_69 (Conv2D)        │ (None, 14, 14, 64)     │         36,928 │ activation_33[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_39    │ (None, 14, 14, 64)     │            256 │ conv2d_69[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_15 (Add)              │ (None, 14, 14, 64)     │              0 │ batch_normalization_3… │
# │                           │                        │                │ activation_32[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_34             │ (None, 14, 14, 64)     │              0 │ add_15[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_70 (Conv2D)        │ (None, 7, 7, 128)      │         73,856 │ activation_34[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_40    │ (None, 7, 7, 128)      │            512 │ conv2d_70[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_35             │ (None, 7, 7, 128)      │              0 │ batch_normalization_4… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_71 (Conv2D)        │ (None, 7, 7, 128)      │        147,584 │ activation_35[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_72 (Conv2D)        │ (None, 7, 7, 128)      │          8,320 │ activation_34[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_41    │ (None, 7, 7, 128)      │            512 │ conv2d_71[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_42    │ (None, 7, 7, 128)      │            512 │ conv2d_72[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_16 (Add)              │ (None, 7, 7, 128)      │              0 │ batch_normalization_4… │
# │                           │                        │                │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_36             │ (None, 7, 7, 128)      │              0 │ add_16[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_73 (Conv2D)        │ (None, 7, 7, 128)      │        147,584 │ activation_36[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_43    │ (None, 7, 7, 128)      │            512 │ conv2d_73[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_37             │ (None, 7, 7, 128)      │              0 │ batch_normalization_4… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_74 (Conv2D)        │ (None, 7, 7, 128)      │        147,584 │ activation_37[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_44    │ (None, 7, 7, 128)      │            512 │ conv2d_74[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_17 (Add)              │ (None, 7, 7, 128)      │              0 │ batch_normalization_4… │
# │                           │                        │                │ activation_36[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_38             │ (None, 7, 7, 128)      │              0 │ add_17[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 128)            │              0 │ activation_38[0][0]    │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_30 (Dense)          │ (None, 128)            │         16,512 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_31 (Dense)          │ (None, 10)             │          1,290 │ dense_30[0][0]         │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 2,143,264 (8.18 MB)
#  Trainable params: 713,674 (2.72 MB)
#  Non-trainable params: 2,240 (8.75 KB)
#  Optimizer params: 1,427,350 (5.44 MB)

# %%
print(f"Final training accuracy: {history_resnet_baseline.history['accuracy'][-1]:.4f}")
print(f"Final validation accuracy: {history_resnet_baseline.history['val_accuracy'][-1]:.4f}")
print(f"Final training loss: {history_resnet_baseline.history['loss'][-1]:.4f}")
print(f"Final validation loss: {history_resnet_baseline.history['val_loss'][-1]:.4f}")

import matplotlib.pyplot as plt

# Plot training & validation accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history_resnet_baseline.history['accuracy'])
plt.plot(history_resnet_baseline.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss
plt.subplot(1, 2, 2)
plt.plot(history_resnet_baseline.history['loss'])
plt.plot(history_resnet_baseline.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()
# Out:
# Final training accuracy: 0.9969
# Final validation accuracy: 0.8817
# Final training loss: 0.0090
# Final validation loss: 0.8123

# %%
# resnet_baseline.evaluate(x_test,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8796 - loss: 0.8763
# [0.8585803508758545, 0.8779000043869019]

# %%
# from sklearn.metrics import confusion_matrix , classification_report

# y_pred_resnet = resnet_baseline.predict(x_test)

# y_classes_resnet = [np.argmax(element) for element in y_pred_resnet]
# print("Classification Report: \n", classification_report(y_test, y_classes_resnet))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.93      0.84      1000
#            1       1.00      0.94      0.97      1000
#            2       0.71      0.94      0.81      1000
#            3       0.89      0.89      0.89      1000
#            4       0.99      0.47      0.64      1000
#            5       0.99      0.95      0.97      1000
#            6       0.69      0.75      0.72      1000
#            7       0.91      0.99      0.95      1000
#            8       0.99      0.96      0.98      1000
#            9       0.99      0.94      0.96      1000
#
#     accuracy                           0.88     10000
#    macro avg       0.89      0.88      0.87     10000
# weighted avg       0.89      0.88      0.87     10000

# %% [markdown]
# # Hyperparameter Grid-Search for CNN

# %%
# !pip install keras_tuner
# Out:
# Collecting keras_tuner
#   Downloading keras_tuner-1.4.7-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras_tuner) (3.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras_tuner) (24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras_tuner) (2.32.3)
# Collecting kt-legacy (from keras_tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras->keras_tuner) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras->keras_tuner) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras->keras_tuner) (13.9.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras->keras_tuner) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras->keras_tuner) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras->keras_tuner) (0.13.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras->keras_tuner) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras_tuner) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras_tuner) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras_tuner) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras_tuner) (2024.8.30)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras->keras_tuner) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras->keras_tuner) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras->keras_tuner) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras_tuner) (0.1.2)
# Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 4.7 MB/s eta 0:00:00
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras_tuner
# Successfully installed keras_tuner-1.4.7 kt-legacy-1.0.5

# %%
import keras_tuner as kt
from tensorflow.keras import layers, models, regularizers
import tensorflow as tf

def build_model(hp):
    model = models.Sequential()

    # First Convolutional Layer
    model.add(layers.Conv2D(
        filters=32,
        kernel_size=(3, 3),
        activation='relu',
        input_shape=(28, 28, 1),
        kernel_regularizer=regularizers.l2(hp.Float('l2_reg', min_value=1e-5, max_value=1e-2, sampling='log'))
    ))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Dropout(hp.Float('dropout_1', min_value=0.0, max_value=0.5, step=0.1)))

    # Second Convolutional Layer
    model.add(layers.Conv2D(
        filters=64,
        kernel_size=(3, 3),
        activation='relu',
        kernel_regularizer=regularizers.l2(hp.Float('l2_reg', min_value=1e-5, max_value=1e-2, sampling='log'))
    ))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Dropout(hp.Float('dropout_2', min_value=0.0, max_value=0.5, step=0.1)))

    model.add(layers.Flatten())

    # Dense Layer
    model.add(layers.Dense(
        units=64,
        activation='relu',
        kernel_regularizer=regularizers.l2(hp.Float('l2_reg', min_value=1e-5, max_value=1e-2, sampling='log'))
    ))
    model.add(layers.Dropout(hp.Float('dropout_3', min_value=0.0, max_value=0.5, step=0.1)))

    # Output Layer
    model.add(layers.Dense(10, activation='softmax'))

    # Compile the model
    optimizer = hp.Choice('optimizer', values=['adam', 'rmsprop', 'sgd'])
    if optimizer == 'adam':
        opt = tf.keras.optimizers.Adam(hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='log'))
    elif optimizer == 'rmsprop':
        opt = tf.keras.optimizers.RMSprop(hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='log'))
    else:
        opt = tf.keras.optimizers.SGD(hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='log'))

    model.compile(
        optimizer=opt,
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# Set up the tuner
tuner = kt.Hyperband(
    build_model,
    objective='val_accuracy',
    max_epochs=50,
    factor=3,
    directory='my_dir',
    project_name='cnn_tuning'
)

# Define early stopping
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

# Perform the search
tuner.search(x_train, y_train,
             epochs=50,
             validation_data=(x_val, y_val),
             callbacks=[early_stopping])

# Get the optimal hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete. The optimal hyperparameters are:
Optimizer: {best_hps.get('optimizer')}
Learning rate: {best_hps.get('learning_rate')}
L2 regularization: {best_hps.get('l2_reg')}
Dropout rates: {best_hps.get('dropout_1')}, {best_hps.get('dropout_2')}, {best_hps.get('dropout_3')}
""")

# Build the model with the optimal hyperparameters and train it on the data
model = tuner.hypermodel.build(best_hps)
history = model.fit(x_train, y_train,
                    epochs=50,
                    validation_data=(x_val, y_val),
                    callbacks=[early_stopping])

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
print(f'Test accuracy: {test_accuracy:.4f}')
# Out:
# Trial 90 Complete [00h 03m 44s]
# val_accuracy: 0.9008333086967468
#
# Best val_accuracy So Far: 0.9076666831970215
# Total elapsed time: 01h 01m 50s
#
# The hyperparameter search is complete. The optimal hyperparameters are:
# Optimizer: adam
# Learning rate: 0.000602765627984751
# L2 regularization: 1.137176368923248e-05
# Dropout rates: 0.1, 0.30000000000000004, 0.2
#
# Epoch 1/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.2980 - loss: 4.7124 - val_accuracy: 0.6909 - val_loss: 0.9381
# Epoch 2/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5978 - loss: 1.1221 - val_accuracy: 0.7217 - val_loss: 0.7389
# Epoch 3/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.6840 - loss: 0.8287 - val_accuracy: 0.8028 - val_loss: 0.5791
# Epoch 4/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7774 - loss: 0.6207 - val_accuracy: 0.8457 - val_loss: 0.4262
# Epoch 5/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8176 - loss: 0.4985 - val_accuracy: 0.8627 - val_loss: 0.3848
# Epoch 6/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8346 - loss: 0.4450 - val_accuracy: 0.8723 - val_loss: 0.3514
# Epoch 7/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8444 - loss: 0.4132 - val_accuracy: 0.8758 - val_loss: 0.3409
# Epoch 8/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8530 - loss: 0.3979 - val_accuracy: 0.8818 - val_loss: 0.3280
# Epoch 9/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8618 - loss: 0.3797 - val_accuracy: 0.8832 - val_loss: 0.3225
# Epoch 10/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8654 - loss: 0.3655 - val_accuracy: 0.8816 - val_loss: 0.3311
# Epoch 11/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8724 - loss: 0.3541 - val_accuracy: 0.8802 - val_loss: 0.3191
# Epoch 12/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8724 - loss: 0.3447 - val_accuracy: 0.8903 - val_loss: 0.3084
# Epoch 13/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8786 - loss: 0.3291 - val_accuracy: 0.8827 - val_loss: 0.3169
# Epoch 14/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8798 - loss: 0.3291 - val_accuracy: 0.8938 - val_loss: 0.2954
# Epoch 15/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8846 - loss: 0.3134 - val_accuracy: 0.8923 - val_loss: 0.2960
# Epoch 16/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8852 - loss: 0.3172 - val_accuracy: 0.8928 - val_loss: 0.2936
# Epoch 17/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8850 - loss: 0.3147 - val_accuracy: 0.8961 - val_loss: 0.2877
# Epoch 18/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8886 - loss: 0.3043 - val_accuracy: 0.8946 - val_loss: 0.2981
# Epoch 19/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8917 - loss: 0.2933 - val_accuracy: 0.8968 - val_loss: 0.2963
# Epoch 20/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8917 - loss: 0.2917 - val_accuracy: 0.8974 - val_loss: 0.2848
# Epoch 21/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8930 - loss: 0.2908 - val_accuracy: 0.9021 - val_loss: 0.2822
# Epoch 22/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8932 - loss: 0.2854 - val_accuracy: 0.9022 - val_loss: 0.2873
# Epoch 23/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8963 - loss: 0.2843 - val_accuracy: 0.8995 - val_loss: 0.2882
# Epoch 24/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8976 - loss: 0.2821 - val_accuracy: 0.8967 - val_loss: 0.2864
# Epoch 25/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8997 - loss: 0.2748 - val_accuracy: 0.9022 - val_loss: 0.2886
# Epoch 26/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8978 - loss: 0.2795 - val_accuracy: 0.9038 - val_loss: 0.2929
# Test accuracy: 0.8969

# %% [markdown]
# # Testing all baseline models

# %%
# from sklearn.metrics import confusion_matrix , classification_report

# y_pred_cnn = cnn.predict(x_test)

# y_classes_cnn = [np.argmax(element) for element in y_pred_cnn]
# print("Classification Report - Baseline CNN: \n", classification_report(y_test, y_classes_cnn))

# print("\n\n")

# y_pred_alexnet = alexnet.predict(x_test)

# y_classes_alexnet = [np.argmax(element) for element in y_pred_alexnet]
# print("Classification Report - AlexNet: \n", classification_report(y_test, y_classes_alexnet))

# print("\n\n")

# y_pred_lenet5 = lenet5_baseline.predict(x_test)

# y_classes_lenet5 = [np.argmax(element) for element in y_pred_lenet5]
# print("Classification Report - LeNet5: \n", classification_report(y_test, y_classes_lenet5))

# print("\n\n")

# y_pred_resnet = resnet_baseline.predict(x_test)

# y_classes_resnet = [np.argmax(element) for element in y_pred_resnet]
# print("Classification Report - ResNet: \n", classification_report(y_test, y_classes_resnet))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Classification Report - Baseline CNN:
#                precision    recall  f1-score   support
#
#            0       0.78      0.88      0.83      1000
#            1       0.99      0.97      0.98      1000
#            2       0.79      0.84      0.81      1000
#            3       0.88      0.89      0.88      1000
#            4       0.81      0.81      0.81      1000
#            5       0.98      0.97      0.98      1000
#            6       0.71      0.58      0.64      1000
#            7       0.95      0.96      0.96      1000
#            8       0.97      0.98      0.97      1000
#            9       0.96      0.96      0.96      1000
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000
#
#
#
#
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Classification Report - AlexNet:
#                precision    recall  f1-score   support
#
#            0       0.82      0.85      0.84      1000
#            1       0.99      0.97      0.98      1000
#            2       0.80      0.88      0.84      1000
#            3       0.87      0.92      0.89      1000
#            4       0.84      0.83      0.83      1000
#            5       0.98      0.97      0.98      1000
#            6       0.75      0.61      0.67      1000
#            7       0.95      0.96      0.96      1000
#            8       0.98      0.98      0.98      1000
#            9       0.96      0.96      0.96      1000
#
#     accuracy                           0.89     10000
#    macro avg       0.89      0.89      0.89     10000
# weighted avg       0.89      0.89      0.89     10000
#
#
#
#
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Classification Report - LeNet5:
#                precision    recall  f1-score   support
#
#            0       0.75      0.82      0.79      1000
#            1       0.98      0.96      0.97      1000
#            2       0.77      0.78      0.77      1000
#            3       0.88      0.86      0.87      1000
#            4       0.74      0.79      0.76      1000
#            5       0.96      0.95      0.96      1000
#            6       0.67      0.55      0.60      1000
#            7       0.93      0.95      0.94      1000
#            8       0.92      0.96      0.94      1000
#            9       0.95      0.95      0.95      1000
#
#     accuracy                           0.86     10000
#    macro avg       0.85      0.86      0.85     10000
# weighted avg       0.85      0.86      0.85     10000
#
#
#
#
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Classification Report - ResNet:
#                precision    recall  f1-score   support
#
#            0       0.77      0.93      0.84      1000
#            1       1.00      0.94      0.97      1000
#            2       0.71      0.94      0.81      1000
#            3       0.89      0.89      0.89      1000
#            4       0.99      0.47      0.64      1000
#            5       0.99      0.95      0.97      1000
#            6       0.69      0.75      0.72      1000
#            7       0.91      0.99      0.95      1000
#            8       0.99      0.96      0.98      1000
#            9       0.99      0.94      0.96      1000
#
#     accuracy                           0.88     10000
#    macro avg       0.89      0.88      0.87     10000
# weighted avg       0.89      0.88      0.87     10000
