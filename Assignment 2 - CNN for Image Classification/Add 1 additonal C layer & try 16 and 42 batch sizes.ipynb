# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import fashion_mnist
from sklearn.model_selection import train_test_split
from tensorflow.keras import models
from tensorflow.keras import layers

# Load the Fashion-MNIST dataset
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# Split data into training and validation sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# Print the shapes of the new sets
print("Training set shape:", x_train.shape)
print("Training labels shape:", y_train.shape)

print("\nValidation set shape:", x_val.shape)
print("Validation set shape:", y_val.shape)

print("\nTest set shape:", x_test.shape)
print("Test labels shape:", y_test.shape)

# Define class names
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Training set shape: (48000, 28, 28)
# Training labels shape: (48000,)
#
# Validation set shape: (12000, 28, 28)
# Validation set shape: (12000,)
#
# Test set shape: (10000, 28, 28)
# Test labels shape: (10000,)

# %%
# #Normalize the data

x_train = (x_train - 0.2860) / 0.3530
x_val = (x_val - 0.2860) / 0.3530
x_test = (x_test - 0.2860) / 0.3530

# %%
x_train = x_train.reshape(-1, 28, 28, 1)
x_val = x_val.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

x_train[0].shape
# Out:
# (28, 28, 1)

# %% [markdown]
# # Add an additional convolutional layer and fit it with a batch-size of 16

# %%
cnn = models.Sequential([
    layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    # Additional layer for more complexity
    layers.Conv2D(filters=128, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from tensorflow.keras.optimizers import Adam

cnn.compile(optimizer=Adam(learning_rate=0.0001),  # Adjust learning rate
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy'])

# %%
baseline_cnn = cnn.fit(x_train, y_train,
                        validation_data=(x_val, y_val),
                        epochs=50,
                        batch_size=16)  # Experiment with smaller batch size
# Out:
# Epoch 1/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - accuracy: 0.3920 - loss: 3.7801 - val_accuracy: 0.6707 - val_loss: 1.0800
# Epoch 2/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.5816 - loss: 1.2305 - val_accuracy: 0.7592 - val_loss: 0.7673
# Epoch 3/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6705 - loss: 0.9388 - val_accuracy: 0.7812 - val_loss: 0.6214
# Epoch 4/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7114 - loss: 0.7823 - val_accuracy: 0.7887 - val_loss: 0.5750
# Epoch 5/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.7429 - loss: 0.7126 - val_accuracy: 0.8138 - val_loss: 0.5243
# Epoch 6/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.7731 - loss: 0.6373 - val_accuracy: 0.8230 - val_loss: 0.4811
# Epoch 7/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.7873 - loss: 0.5929 - val_accuracy: 0.8300 - val_loss: 0.4631
# Epoch 8/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8008 - loss: 0.5524 - val_accuracy: 0.8437 - val_loss: 0.4526
# Epoch 9/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8129 - loss: 0.5204 - val_accuracy: 0.8431 - val_loss: 0.4219
# Epoch 10/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8183 - loss: 0.5057 - val_accuracy: 0.8537 - val_loss: 0.4086
# Epoch 11/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8314 - loss: 0.4697 - val_accuracy: 0.8572 - val_loss: 0.3885
# Epoch 12/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8397 - loss: 0.4441 - val_accuracy: 0.8587 - val_loss: 0.4002
# Epoch 13/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8438 - loss: 0.4300 - val_accuracy: 0.8643 - val_loss: 0.3855
# Epoch 14/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8557 - loss: 0.3999 - val_accuracy: 0.8711 - val_loss: 0.3738
# Epoch 15/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8607 - loss: 0.3823 - val_accuracy: 0.8713 - val_loss: 0.3726
# Epoch 16/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8622 - loss: 0.3714 - val_accuracy: 0.8648 - val_loss: 0.4147
# Epoch 17/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8683 - loss: 0.3650 - val_accuracy: 0.8742 - val_loss: 0.3655
# Epoch 18/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8726 - loss: 0.3461 - val_accuracy: 0.8792 - val_loss: 0.3650
# Epoch 19/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.8779 - loss: 0.3305 - val_accuracy: 0.8757 - val_loss: 0.3742
# Epoch 20/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8829 - loss: 0.3204 - val_accuracy: 0.8817 - val_loss: 0.3585
# Epoch 21/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8886 - loss: 0.3043 - val_accuracy: 0.8796 - val_loss: 0.3664
# Epoch 22/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8875 - loss: 0.3013 - val_accuracy: 0.8817 - val_loss: 0.3667
# Epoch 23/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8924 - loss: 0.2928 - val_accuracy: 0.8854 - val_loss: 0.3817
# Epoch 24/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8963 - loss: 0.2826 - val_accuracy: 0.8786 - val_loss: 0.3871
# Epoch 25/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8989 - loss: 0.2716 - val_accuracy: 0.8817 - val_loss: 0.3983
# Epoch 26/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9042 - loss: 0.2648 - val_accuracy: 0.8826 - val_loss: 0.3963
# Epoch 27/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9058 - loss: 0.2529 - val_accuracy: 0.8802 - val_loss: 0.4040
# Epoch 28/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9113 - loss: 0.2397 - val_accuracy: 0.8815 - val_loss: 0.4012
# Epoch 29/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9090 - loss: 0.2396 - val_accuracy: 0.8848 - val_loss: 0.3928
# Epoch 30/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9142 - loss: 0.2321 - val_accuracy: 0.8817 - val_loss: 0.4302
# Epoch 31/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9168 - loss: 0.2272 - val_accuracy: 0.8857 - val_loss: 0.4413
# Epoch 32/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9219 - loss: 0.2141 - val_accuracy: 0.8876 - val_loss: 0.4185
# Epoch 33/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9237 - loss: 0.2050 - val_accuracy: 0.8832 - val_loss: 0.4199
# Epoch 34/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9216 - loss: 0.2064 - val_accuracy: 0.8836 - val_loss: 0.4200
# Epoch 35/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9263 - loss: 0.1929 - val_accuracy: 0.8867 - val_loss: 0.4326
# Epoch 36/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9283 - loss: 0.1866 - val_accuracy: 0.8873 - val_loss: 0.4235
# Epoch 37/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9303 - loss: 0.1867 - val_accuracy: 0.8871 - val_loss: 0.4456
# Epoch 38/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9335 - loss: 0.1796 - val_accuracy: 0.8850 - val_loss: 0.4314
# Epoch 39/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9332 - loss: 0.1827 - val_accuracy: 0.8841 - val_loss: 0.4295
# Epoch 40/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9320 - loss: 0.1771 - val_accuracy: 0.8863 - val_loss: 0.4894
# Epoch 41/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9366 - loss: 0.1687 - val_accuracy: 0.8891 - val_loss: 0.4929
# Epoch 42/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9385 - loss: 0.1634 - val_accuracy: 0.8852 - val_loss: 0.5243
# Epoch 43/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9410 - loss: 0.1567 - val_accuracy: 0.8848 - val_loss: 0.4880
# Epoch 44/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9449 - loss: 0.1529 - val_accuracy: 0.8850 - val_loss: 0.5410
# Epoch 45/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9454 - loss: 0.1436 - val_accuracy: 0.8826 - val_loss: 0.5400
# Epoch 46/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9454 - loss: 0.1480 - val_accuracy: 0.8874 - val_loss: 0.5817
# Epoch 47/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9477 - loss: 0.1452 - val_accuracy: 0.8878 - val_loss: 0.5523
# Epoch 48/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9496 - loss: 0.1387 - val_accuracy: 0.8821 - val_loss: 0.5563
# Epoch 49/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9499 - loss: 0.1377 - val_accuracy: 0.8836 - val_loss: 0.5536
# Epoch 50/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9503 - loss: 0.1360 - val_accuracy: 0.8878 - val_loss: 0.5994

# %%
print(f"Final training accuracy: {baseline_cnn.history['accuracy'][-1]:.4f}")
print(f"Final validation accuracy: {baseline_cnn.history['val_accuracy'][-1]:.4f}")
print(f"Final training loss: {baseline_cnn.history['loss'][-1]:.4f}")
print(f"Final validation loss: {baseline_cnn.history['val_loss'][-1]:.4f}")

import matplotlib.pyplot as plt

# Plot training & validation accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(baseline_cnn.history['accuracy'])
plt.plot(baseline_cnn.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss
plt.subplot(1, 2, 2)
plt.plot(baseline_cnn.history['loss'])
plt.plot(baseline_cnn.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()
# Out:
# Final training accuracy: 0.9494
# Final validation accuracy: 0.8878
# Final training loss: 0.1368
# Final validation loss: 0.5994

# %% [markdown]
# # Add an additional convolutional layer and fit it with a batch-size of 32

# %%
from tensorflow.keras.optimizers import Adam

cnn_2 = models.Sequential([
    layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    # Additional layer for more complexity
    layers.Conv2D(filters=128, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(10, activation='softmax')
])


cnn_2.compile(optimizer=Adam(learning_rate=0.001),  # Adjust learning rate
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy'])

baseline_cnn_2 = cnn_2.fit(x_train, y_train,
                        validation_data=(x_val, y_val),
                        epochs=50,
                        batch_size=32)  # Experiment with smaller batch size
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.4749 - loss: 2.1748 - val_accuracy: 0.7889 - val_loss: 0.5839
# Epoch 2/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7542 - loss: 0.6699 - val_accuracy: 0.8225 - val_loss: 0.4823
# Epoch 3/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7906 - loss: 0.5786 - val_accuracy: 0.8198 - val_loss: 0.4853
# Epoch 4/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8223 - loss: 0.4954 - val_accuracy: 0.8410 - val_loss: 0.4248
# Epoch 5/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8283 - loss: 0.4621 - val_accuracy: 0.8453 - val_loss: 0.4087
# Epoch 6/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8357 - loss: 0.4426 - val_accuracy: 0.8497 - val_loss: 0.3990
# Epoch 7/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8465 - loss: 0.4194 - val_accuracy: 0.8472 - val_loss: 0.4198
# Epoch 8/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8553 - loss: 0.3979 - val_accuracy: 0.8652 - val_loss: 0.3751
# Epoch 9/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8607 - loss: 0.3774 - val_accuracy: 0.8663 - val_loss: 0.3705
# Epoch 10/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8674 - loss: 0.3564 - val_accuracy: 0.8599 - val_loss: 0.3861
# Epoch 11/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8684 - loss: 0.3416 - val_accuracy: 0.8637 - val_loss: 0.3879
# Epoch 12/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8751 - loss: 0.3364 - val_accuracy: 0.8577 - val_loss: 0.4308
# Epoch 13/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8751 - loss: 0.3351 - val_accuracy: 0.8687 - val_loss: 0.3854
# Epoch 14/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8820 - loss: 0.3196 - val_accuracy: 0.8667 - val_loss: 0.3970
# Epoch 15/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8803 - loss: 0.3209 - val_accuracy: 0.8723 - val_loss: 0.4020
# Epoch 16/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8889 - loss: 0.3033 - val_accuracy: 0.8726 - val_loss: 0.3830
# Epoch 17/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8879 - loss: 0.2963 - val_accuracy: 0.8725 - val_loss: 0.3879
# Epoch 18/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8904 - loss: 0.2940 - val_accuracy: 0.8740 - val_loss: 0.4021
# Epoch 19/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8923 - loss: 0.2853 - val_accuracy: 0.8692 - val_loss: 0.4158
# Epoch 20/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8952 - loss: 0.2834 - val_accuracy: 0.8708 - val_loss: 0.4314
# Epoch 21/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8973 - loss: 0.2758 - val_accuracy: 0.8749 - val_loss: 0.4086
# Epoch 22/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8917 - loss: 0.2763 - val_accuracy: 0.8679 - val_loss: 0.4600
# Epoch 23/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8960 - loss: 0.2774 - val_accuracy: 0.8675 - val_loss: 0.4567
# Epoch 24/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9015 - loss: 0.2599 - val_accuracy: 0.8778 - val_loss: 0.4234
# Epoch 25/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9053 - loss: 0.2521 - val_accuracy: 0.8693 - val_loss: 0.4605
# Epoch 26/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9003 - loss: 0.2676 - val_accuracy: 0.8694 - val_loss: 0.4816
# Epoch 27/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9070 - loss: 0.2498 - val_accuracy: 0.8776 - val_loss: 0.4313
# Epoch 28/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9073 - loss: 0.2473 - val_accuracy: 0.8686 - val_loss: 0.4711
# Epoch 29/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9084 - loss: 0.2453 - val_accuracy: 0.8639 - val_loss: 0.5388
# Epoch 30/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9041 - loss: 0.2560 - val_accuracy: 0.8737 - val_loss: 0.5283
# Epoch 31/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9087 - loss: 0.2432 - val_accuracy: 0.8717 - val_loss: 0.5600
# Epoch 32/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9079 - loss: 0.2569 - val_accuracy: 0.8741 - val_loss: 0.5226
# Epoch 33/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9136 - loss: 0.2371 - val_accuracy: 0.8735 - val_loss: 0.5382
# Epoch 34/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9160 - loss: 0.2349 - val_accuracy: 0.8742 - val_loss: 0.5929
# Epoch 35/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9113 - loss: 0.2441 - val_accuracy: 0.8689 - val_loss: 0.5967
# Epoch 36/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9122 - loss: 0.2387 - val_accuracy: 0.8612 - val_loss: 0.6242
# Epoch 37/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9122 - loss: 0.2389 - val_accuracy: 0.8696 - val_loss: 0.5443
# Epoch 38/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9172 - loss: 0.2257 - val_accuracy: 0.8764 - val_loss: 0.5424
# Epoch 39/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9165 - loss: 0.2282 - val_accuracy: 0.8536 - val_loss: 0.5560
# Epoch 40/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9133 - loss: 0.2406 - val_accuracy: 0.8553 - val_loss: 0.6570
# Epoch 41/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9128 - loss: 0.2368 - val_accuracy: 0.8717 - val_loss: 0.5986
# Epoch 42/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9228 - loss: 0.2044 - val_accuracy: 0.8684 - val_loss: 0.6138
# Epoch 43/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9202 - loss: 0.2128 - val_accuracy: 0.8698 - val_loss: 0.6245
# Epoch 44/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9150 - loss: 0.2373 - val_accuracy: 0.8714 - val_loss: 0.6976
# Epoch 45/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9271 - loss: 0.1994 - val_accuracy: 0.8725 - val_loss: 0.6107
# Epoch 46/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9194 - loss: 0.2192 - val_accuracy: 0.8671 - val_loss: 0.6306
# Epoch 47/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9264 - loss: 0.2001 - val_accuracy: 0.8742 - val_loss: 0.6460
# Epoch 48/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9262 - loss: 0.2026 - val_accuracy: 0.8723 - val_loss: 0.6164
# Epoch 49/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9247 - loss: 0.2101 - val_accuracy: 0.8727 - val_loss: 0.6667
# Epoch 50/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9234 - loss: 0.2023 - val_accuracy: 0.8726 - val_loss: 0.7395

# %%
print(f"Final training accuracy: {baseline_cnn_2.history['accuracy'][-1]:.4f}")
print(f"Final validation accuracy: {baseline_cnn_2.history['val_accuracy'][-1]:.4f}")
print(f"Final training loss: {baseline_cnn_2.history['loss'][-1]:.4f}")
print(f"Final validation loss: {baseline_cnn_2.history['val_loss'][-1]:.4f}")

import matplotlib.pyplot as plt

# Plot training & validation accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(baseline_cnn_2.history['accuracy'])
plt.plot(baseline_cnn_2.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss
plt.subplot(1, 2, 2)
plt.plot(baseline_cnn_2.history['loss'])
plt.plot(baseline_cnn_2.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()
# Out:
# Final training accuracy: 0.9186
# Final validation accuracy: 0.8726
# Final training loss: 0.2236
# Final validation loss: 0.7395
